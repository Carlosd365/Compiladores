# %%
import pandas as pd
import re
from PyPDF2 import PdfReader

rutaArch = "Analisis Anual 2018 ETAS.pdf"

documento = PdfReader(rutaArch)

dir(documento)

len(documento.pages)
# Out:
# 19

# %%
pagina = documento.pages[11]
texto = pagina.extract_text() 
texto
# Out:
# '  \nMinisterio de Salud Pública y Asistencia Social -MSPAS - \nDepartamento de Epidemiologia ///2471 -5680  \n6 avenida 3 -45, zona 11, Guatemala, Guatemala.  \n \n \n \n \n \nLas 5  áreas de salud con \nmayor incremento de tasa de \nincidencia para el año 2018  \nson: Ixil, Sololá, San marcos, \nAlta Verapaz y Totonicapán , \nmismas que se encuentran \npor arriba de la tasa total país  \nAsí también e s importante \nidentificar a las 3  áreas de \nsalud que reportaron más \nnúmero de  casos en relación \nal año 2018  y son: Ixil 412 \ncasos, Alta Verapaz  468 \ncasos y  San Marcos 355 \ncasos.  \n \n \n \n \n                                                           \nEn relación a los grupos de edad y \nsexo, la Disentería afecta  a dos \ngrandes grupos de edad y cada \nuno en diferente sexo:  \n1) Los infantes de 2 a 11 \nmeses de edad (111 masculinos \npor 100,000 habitantes  y 89 \nfemeninas por 100,000 \nhabitantes),  \n2) Los niños (as) de 1 a 4 años \nde edad (17,208 niños por \n100,000 habitantes y 16,854 \nniñas por 100,000 habitantes).  \n Cuadro 6. Disentería:  \nCasos y Tasas Acumulados  por  Área de Salud  \nGuatemala 2017 - 2018  \nAREA DE SALUD  2017  2018  \nCasos  Tasas  Casos  Tasas  \nIxil 4 2.00 416 201.20  \nSololá  469 90.25  577 108.06  \nSan Marcos  921 78.48  1276  106.37  \nAlta Verapaz  758 56.89  1226  89.41  \nTotonicapán  72 12.65  260 44.40  \nIzabal  154 32.21  183 37.39  \nRetalhuleu  118 33.95  119 33.52  \nZacapa  70 28.59  76 30.50  \nPetén Sur Oriental  28 11.33  37 14.57  \nEscuintla  12 1.52 98 12.16  \nEl Quiche  68 8.06 104 11.96  \nBaja Verapaz  14 4.44 30 9.28 \nPetén Norte  2 0.82 18 7.13 \nHuehuetenango  47 3.53 63 4.63 \nQuetzaltenango  22 2.44 39 4.23 \nEl Progreso  1 0.57 7 3.92 \nGuatemala Central  42 4.22 36 3.62 \nJutiapa  0   16 3.18 \nSanta Rosa  2 0.51 11 2.76 \nIxcán  1 0.84 3 2.43 \nChimaltenango  4 0.55 11 1.48 \nSacatepéquez  59 16.55  4 1.10 \nGuatemala Sur  8 0.74 10 0.91 \nPetén Sur Occidental  0   2 0.66 \nGuatemala Nor Occidente  7 0.83 5 0.59 \nSuchitepéquez  0   3 0.49 \nGuatemala Nor Oriente  0   2 0.37 \nChiquimula  1 0.23 1 0.23 \nTotal PAIS  2884  17.03  4633  26.76  \nFuente: SIGSA      \n*Tasa por 100,000 habitantes      \n0.444.3688.97108.1224.199.958.7620.8824.6520.8421.9916.566.579.52\n0.002.93111.45102.8721.608.683.874.398.9511.209.289.954.499.78\nMenor de 1 mesDe 1 a 2 mesesDe 2 a 11 mesesDe 1 a 4 añosDe 5 a 9 añosDe 10 a 14 añosDe 15 a 19 añosDe 20 a 24 añosDe 25 a 39 añosDe 40 a 49 añosDe 50 a 59 añosDe 60 a 64 añosDe 65 a 69 añosMayores de 70 años\nTasa Hombres Tasa Mujeres\nFuente: SIGSA\n*Tasa por 100,000 habitantes Grafico 11. Disentería: Tasas por sexo y \nedad, Guatemala 2017 -2018  \n '

# %%
patron = r'\n(\w+\s*\W+\s*\w*)\s+(\d+)\s+(\d+.\d+)\s+(\d+)\s+(\d+.\d+)'

datos = re.findall(patron, texto)
datos
# Out:
# [('Sololá ', '469', '90.25', '577', '108.06'),
#  ('San Marcos', '921', '78.48', '1276', '106.37'),
#  ('Alta Verapaz', '758', '56.89', '1226', '89.41'),
#  ('Totonicapán ', '72', '12.65', '260', '44.40'),
#  ('Izabal ', '154', '32.21', '183', '37.39'),
#  ('Retalhuleu ', '118', '33.95', '119', '33.52'),
#  ('Zacapa ', '70', '28.59', '76', '30.50'),
#  ('Escuintla ', '12', '1.52', '98', '12.16'),
#  ('El Quiche', '68', '8.06', '104', '11.96'),
#  ('Baja Verapaz', '14', '4.44', '30', '9.28'),
#  ('Petén Norte', '2', '0.82', '18', '7.13'),
#  ('Huehuetenango ', '47', '3.53', '63', '4.63'),
#  ('Quetzaltenango ', '22', '2.44', '39', '4.23'),
#  ('El Progreso', '1', '0.57', '7', '3.92'),
#  ('Guatemala Central', '42', '4.22', '36', '3.62'),
#  ('Santa Rosa', '2', '0.51', '11', '2.76'),
#  ('Ixcán ', '1', '0.84', '3', '2.43'),
#  ('Chimaltenango ', '4', '0.55', '11', '1.48'),
#  ('Sacatepéquez ', '59', '16.55', '4', '1.10'),
#  ('Guatemala Sur', '8', '0.74', '10', '0.91'),
#  ('Chiquimula ', '1', '0.23', '1', '0.23'),
#  ('Total PAIS', '2884', '17.03', '4633', '26.76')]

# %%
etas = pd.DataFrame(datos, columns=['Area de Salud', 'Casos 2017', 'Tasas 2017', 'Casos 2018', 'Tasas 2018'])
etas
# Out:
#         Area de Salud Casos 2017 Tasas 2017 Casos 2018 Tasas 2018
# 0             Sololá         469      90.25        577     108.06
# 1          San Marcos        921      78.48       1276     106.37
# 2        Alta Verapaz        758      56.89       1226      89.41
# 3        Totonicapán          72      12.65        260      44.40
# 4             Izabal         154      32.21        183      37.39
# 5         Retalhuleu         118      33.95        119      33.52
# 6             Zacapa          70      28.59         76      30.50
# 7          Escuintla          12       1.52         98      12.16
# 8           El Quiche         68       8.06        104      11.96
# 9        Baja Verapaz         14       4.44         30       9.28
# 10        Petén Norte          2       0.82         18       7.13
# 11     Huehuetenango          47       3.53         63       4.63
# 12    Quetzaltenango          22       2.44         39       4.23
# 13        El Progreso          1       0.57          7       3.92
# 14  Guatemala Central         42       4.22         36       3.62
# 15         Santa Rosa          2       0.51         11       2.76
# 16             Ixcán           1       0.84          3       2.43
# 17     Chimaltenango           4       0.55         11       1.48
# 18      Sacatepéquez          59      16.55          4       1.10
# 19      Guatemala Sur          8       0.74         10       0.91
# 20        Chiquimula           1       0.23          1       0.23
# 21         Total PAIS       2884      17.03       4633      26.76

# %%
etas['Casos 2017'] = etas['Casos 2017'].astype('int64')
etas['Casos 2018'] = etas['Casos 2018'].astype('int64')
etas['Tasas 2017'] = etas['Tasas 2017'].astype('float64')
etas['Tasas 2018'] = etas['Tasas 2018'].astype('float64')
etas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Area de Salud  22 non-null     object
#  1   Casos 2017     22 non-null     int64
#  2   Tasas 2017     22 non-null     float64
#  3   Casos 2018     22 non-null     int64
#  4   Tasas 2018     22 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1012.0+ bytes

# %%
#Cuando se quiere cambiar o se ven afectados todos los datos
#etas = etas.astype({'Casos 2018':'int64', 'Tasas 2018':'float64'})
